# %% [markdown]
# #**Scraping & Crawling Data**
# #**Nama : Alya Fauziyah**
# #**NIM : 21110030**

# %%
# Install  Google play scraper
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.6-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.6

# %%
# Import library
from google_play_scraper import Sort, reviews, app

import pandas as pd

import numpy as np

# %%
# Scrape data

result, continuation_token = reviews(
    'com.tokopedia.tkpd',
    lang='id', # Bahasa
    country='id', # Negara
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=10000, # Jumlah scrape
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
data = pd.DataFrame(np.array(result), columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))

# %%
data
# Out:
#                                   reviewId             userName  \
# 0     f53cd1e4-a3f1-405d-baa5-b7d13658ec37     Rahmad kurniawan
# 1     ff3b4aba-0d06-4354-944a-2366d74c9a83         Sunardi Solo
# 2     00f78182-8e7b-4f12-b8a7-c255cf99d31d          Regan Storm
# 3     515886f4-9999-4595-94c5-93be40f4c8d0  Azril Ilham fajrian
# 4     8f3c9131-d05c-44f2-b9e7-67cc7960bee7       Triagus Ananto
# ...                                    ...                  ...
# 9995  80241aa5-faf1-4f3e-902e-c47339911855    Yohanis Temorubun
# 9996  a59524b7-7d45-4fef-b5a8-adb1a7e3f27e      Pengguna Google
# 9997  c6e0ba9a-df19-4b83-bd8a-62fd5515a7eb             ERNAWATI
# 9998  1f2f5b47-6a42-453b-ac86-d1fb4d61ffb6             LIUR MAS
# 9999  11150601-2584-4af3-9cdc-b4533aa46b1b      Pengguna Google
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a/ACg8oc...
# 1     https://play-lh.googleusercontent.com/a/ACg8oc...
# 2     https://play-lh.googleusercontent.com/a/ACg8oc...
# 3     https://play-lh.googleusercontent.com/a-/ALV-U...
# 4     https://play-lh.googleusercontent.com/a/ACg8oc...
# ...                                                 ...
# 9995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9996  https://play-lh.googleusercontent.com/EGemoI2N...
# 9997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9999  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                 content  score  thumbsUpCount  \
# 0     Saya pelanggan dari dulu . Semakin hari Tokope...      1            140
# 1     Aplikasi ampas, Udh lemot, voucher sering ilan...      1              4
# 2     Sudah benar benar kecewa sama Tokopedia, siste...      1             34
# 3     Jujur saya sangat kecewa dengan kebijakan toko...      1             94
# 4     Tokopedia dengan kurir rekomendasi nya, justru...      2             45
# ...                                                 ...    ...            ...
# 9995  Menurut saya , kompilasi lagu ambon sangat bag...      4              0
# 9996  Saya kecewa dengan tokopedia Masa tidak bisa m...      1             39
# 9997  Saya suka sekali karna semua nya tersedia d si...      5              0
# 9998  Kata orang belanja di tokopedia ngeri2 sedap.....      5              2
# 9999  Lama lama makin ga beres ni aplikasi, Login ak...      1             23
#
#      reviewCreatedVersion                  at  \
# 0                   3.250 2024-01-30 13:30:05
# 1                   3.251 2024-02-02 14:07:57
# 2                   3.250 2024-01-28 05:55:08
# 3                   3.250 2024-01-27 23:32:56
# 4                   3.250 2024-01-31 06:10:46
# ...                   ...                 ...
# 9995                 None 2022-02-21 00:08:20
# 9996               3.52.1 2019-11-26 14:41:23
# 9997                 3.90 2020-09-07 13:55:53
# 9998                 3.87 2020-10-30 13:58:23
# 9999                 3.12 2018-12-26 04:11:31
#
#                                            replyContent           repliedAt  \
# 0     Hi Toppers, silakan sampaikan kritik/saran ata... 2024-01-30 13:40:02
# 1     Halo Toppers, terima kasih atas rating yang ka... 2024-02-02 14:20:04
# 2     Toppers, mohon maaf atas kendala yang kamu ala... 2024-01-28 06:00:08
# 3     Hi Toppers, silakan sampaikan kritik/saran ata... 2024-01-27 23:40:05
# 4     Hi Toppers, silakan sampaikan kritik/saran ata... 2024-01-31 06:20:11
# ...                                                 ...                 ...
# 9995  Hai Toppers, Terima kasih untuk rating yang te... 2022-02-21 00:25:30
# 9996  Hai Toppers, mohon maaf atas ketidaknyamananny... 2019-11-27 01:31:06
# 9997                                               None                 NaT
# 9998                                               None                 NaT
# 9999  Hai Anton, mohon maaf sekali ya atas kendala y... 2018-12-26 06:25:56
#
#      appVersion
# 0         3.250
# 1         3.251
# 2         3.250
# 3         3.250
# 4         3.250
# ...         ...
# 9995       None
# 9996     3.52.1
# 9997       3.90
# 9998       3.87
# 9999       3.12
#
# [10000 rows x 11 columns]

# %%
len(data.index) # count the number of data we got
# Out:
# 10000

# %%
# Unduh hasil scraping
data.to_csv('Hasil scrap tokped.csv')
